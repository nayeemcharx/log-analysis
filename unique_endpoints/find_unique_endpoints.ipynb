# %%
import pandas as pd
def find_unique_endpoints(file_path):

    # Load the CSV file into a pandas DataFrame
    df = pd.read_csv(file_path)

    # Remove query parameters from the URL (split by '?' and keep the first part)
    df['endpoint'] = df['url'].apply(lambda x: x.split('?')[0])

    # Get unique combinations of 'endpoint' and 'method'
    unique_combinations = df[['endpoint', 'method']].drop_duplicates()

    # Save the unique combinations to a new CSV file
    unique_combinations.to_csv(file_path.split('/')[-1], index=False)

    print("CSV file with unique endpoint-method combinations has been created: 'unique_endpoint_method_combinations.csv'")

# %%
find_unique_endpoints('./../healthioProxy.csv')
# Out:
# CSV file with unique endpoint-method combinations has been created: 'unique_endpoint_method_combinations.csv'

# %%
import pandas as pd
def onlyGraphQl(file_path):

    # Load the new CSV file with unique combinations
    df = pd.read_csv(file_path)

    # Include only rows where the endpoint contains '/graphql' (case-insensitive)
    filtered_df = df[df['endpoint'].str.contains('/graphql', case=False)]

    # Save the filtered data to a new CSV file
    filtered_df.to_csv(f'graphql_{file_path}', index=False)

    print("Filtered CSV file has been created: 'graphql_endpoint_method_combinations.csv'")

# %%
onlyGraphQl('healthio.csv')
# Out:
# Filtered CSV file has been created: 'graphql_endpoint_method_combinations.csv'

# %%
import pandas as pd
import json
import re

# Load the CSV file into a pandas DataFrame
df = pd.read_csv('./../healthioProxy.csv')

# Filter to include only rows where the endpoint contains '/graphql' (case-insensitive)
graphql_df = df[df['url'].str.contains('/graphql', case=False)]

# Function to extract the operation name from the 'query' key in the request_body
def extract_operation_name_from_query(body):
    if isinstance(body, str):  # Check if the body is a string
        try:
            # Parse the body as JSON
            body_dict = json.loads(body.replace('""', '"'))  # Fix escaped quotes
            query = body_dict.get('query', '')  # Extract the 'query' field
            
            # Strip leading/trailing whitespace and newlines
            query = query.strip()

            # Use regex to find 'query' or 'mutation' and capture the word that follows
            match = re.search(r'(query|mutation)\s*([a-zA-Z_][\w]*)', query)
            if match:
                return match.group(2)  # Return the operation name (the second capture group)
            else:
                return 'Unknown'  # If no match is found, return 'Unknown'
        except (json.JSONDecodeError, TypeError):
            return 'Unknown'
    else:
        return 'Unknown'

# Function to extract the first occurrence of 'query' or 'mutation' from the 'query' key in the request_body
def extract_query_type(body):
    if isinstance(body, str):  # Check if the body is a string
        try:
            # Parse the body as JSON
            body_dict = json.loads(body.replace('""', '"'))  # Fix escaped quotes
            query = body_dict.get('query', '')  # Extract the 'query' field
            query = query.strip()  # Strip leading/trailing whitespace and newlines
            
            # Use regex to find 'query' or 'mutation'
            match = re.search(r'(query|mutation)', query)
            if match:
                return match.group(1)  # Return 'query' or 'mutation'
            else:
                return 'Unknown'
        except (json.JSONDecodeError, TypeError):
            return 'Unknown'
    else:
        return 'Unknown'

# Apply the functions to extract 'operationName' and 'query_type' from the request_body
graphql_df['operationName'] = graphql_df['request_body'].apply(extract_operation_name_from_query)
graphql_df['query_type'] = graphql_df['request_body'].apply(extract_query_type)

# Filter out rows where 'operationName' is 'Unknown'
graphql_df = graphql_df[graphql_df['operationName'] != 'Unknown']

# Get unique combinations of 'url' (endpoint), 'operationName', and 'query_type'
unique_combinations = graphql_df[['url', 'operationName', 'query_type']].drop_duplicates()

# Save the unique combinations to a new CSV file
unique_combinations.to_csv('graphql_endpoint_operation_query_combinations.csv', index=False)

print("Filtered CSV file with unique endpoint-operationName-query combinations has been created: 'graphql_endpoint_operation_query_combinations.csv'")
# Out:
# {"operationName":"GetUser","variables":{},"query":"query GetUser {\n  user {\n    email\n    firstName\n    createdAt\n    dateOfBirth\n    uuid\n    languagePreference\n    sexAssigned\n    returning\n    isOptum\n    tags\n    applicationPathway {\n      indication\n      program\n      __typename\n    }\n    client {\n      identifier\n      availablePrograms\n      dmcEnabled\n      tabletRequired\n      globalProduct\n      config {\n        supportsUnification\n        m1Trial\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetUser","variables":{},"query":"query GetUser {\n  user {\n    email\n    firstName\n    createdAt\n    dateOfBirth\n    uuid\n    languagePreference\n    sexAssigned\n    returning\n    isOptum\n    tags\n    applicationPathway {\n      indication\n      program\n      __typename\n    }\n    client {\n      identifier\n      availablePrograms\n      dmcEnabled\n      tabletRequired\n      globalProduct\n      config {\n        supportsUnification\n        m1Trial\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetUser","variables":{},"query":"query GetUser {\n  user {\n    email\n    firstName\n    createdAt\n    dateOfBirth\n    uuid\n    languagePreference\n    sexAssigned\n    returning\n    isOptum\n    tags\n    applicationPathway {\n      indication\n      program\n      __typename\n    }\n    client {\n      identifier\n      availablePrograms\n      dmcEnabled\n      tabletRequired\n      globalProduct\n      config {\n        supportsUnification\n        m1Trial\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetPersonalReferralCode","variables":{},"query":"query GetPersonalReferralCode {\n  personalReferralCode {\n    referralKey\n    __typename\n  }\n}\n"}
# {"operationName":"dashboardUserApplications","variables":{},"query":"query dashboardUserApplications {\n  userApplications(\n    input: {type: [CORE, UNIFIED_ENTRY, GLOBAL_PRODUCT], includeClosed: true}\n  ) {\n    ...CommonApplicationUnionFields\n    ... on UnifiedEntryApplication {\n      indications {\n        bodyPart\n        acuity\n        priority\n        __typename\n      }\n      unifiedProgram: program\n      unifiedIndication: indication\n      __typename\n    }\n    ... on CoreApplication {\n      coreProgram: program\n      coreIndication: indication\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment CommonApplicationUnionFields on ApplicationBase {\n  __typename\n  id\n  type\n  progress\n  standing\n  rejectionReasons\n}\n"}
# {"operationName":"GetUserCareProviders","variables":{"input":{"providerType":"COACH"}},"query":"query GetUserCareProviders($input: CareProviderInput!) {\n  user {\n    uuid\n    careProviders(input: $input) {\n      firstName\n      lastName\n      avatarUrl\n      qualifications\n      bio\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetUserCareProviders","variables":{"input":{"providerType":"OS"}},"query":"query GetUserCareProviders($input: CareProviderInput!) {\n  user {\n    uuid\n    careProviders(input: $input) {\n      firstName\n      lastName\n      avatarUrl\n      qualifications\n      bio\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetDashboardPageButtonsToShow","variables":{},"query":"query GetDashboardPageButtonsToShow {\n  dashboardPageButtonsToShow {\n    shouldSeeAboutMyCoachPageLink\n    shouldSeeBalanceProgramLink\n    shouldSeeCanTransferToPhoenixLink\n    shouldSeeCompleteApplicationLink\n    shouldSeeIsEnsoEligibleLink\n    shouldSeeApplyToNewProgramLink\n    shouldSeeCanApplyLink\n    shouldSeePreferencesPageLink\n    shouldSeeProgramInformationPageLink\n    shouldSeeUnifiedCompleteApplicationLink\n    shouldSeeGlobalCompleteApplicationLink\n    __typename\n  }\n}\n"}
# {"operationName":"GetUser","variables":{},"query":"query GetUser {\n  user {\n    email\n    firstName\n    createdAt\n    dateOfBirth\n    uuid\n    languagePreference\n    sexAssigned\n    returning\n    isOptum\n    tags\n    applicationPathway {\n      indication\n      program\n      __typename\n    }\n    client {\n      identifier\n      availablePrograms\n      dmcEnabled\n      tabletRequired\n      globalProduct\n      config {\n        supportsUnification\n        m1Trial\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetUser","variables":{},"query":"query GetUser {\n  user {\n    email\n    firstName\n    createdAt\n    dateOfBirth\n    uuid\n    languagePreference\n    sexAssigned\n    returning\n    isOptum\n    tags\n    applicationPathway {\n      indication\n      program\n      __typename\n    }\n    client {\n      identifier\n      availablePrograms\n      dmcEnabled\n      tabletRequired\n      globalProduct\n      config {\n        supportsUnification\n        m1Trial\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetUser","variables":{},"query":"query GetUser {\n  user {\n    email\n    firstName\n    createdAt\n    dateOfBirth\n    uuid\n    languagePreference\n    sexAssigned\n    returning\n    isOptum\n    tags\n    applicationPathway {\n      indication\n      program\n      __typename\n    }\n    client {\n      identifier\n      availablePrograms\n      dmcEnabled\n      tabletRequired\n      globalProduct\n      config {\n        supportsUnification\n        m1Trial\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetPersonalReferralCode","variables":{},"query":"query GetPersonalReferralCode {\n  personalReferralCode {\n    referralKey\n    __typename\n  }\n}\n"}
# {"operationName":"dashboardUserApplications","variables":{},"query":"query dashboardUserApplications {\n  userApplications(\n    input: {type: [CORE, UNIFIED_ENTRY, GLOBAL_PRODUCT], includeClosed: true}\n  ) {\n    ...CommonApplicationUnionFields\n    ... on UnifiedEntryApplication {\n      indications {\n        bodyPart\n        acuity\n        priority\n        __typename\n      }\n      unifiedProgram: program\n      unifiedIndication: indication\n      __typename\n    }\n    ... on CoreApplication {\n      coreProgram: program\n      coreIndication: indication\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment CommonApplicationUnionFields on ApplicationBase {\n  __typename\n  id\n  type\n  progress\n  standing\n  rejectionReasons\n}\n"}
# {"operationName":"GetUserCareProviders","variables":{"input":{"providerType":"COACH"}},"query":"query GetUserCareProviders($input: CareProviderInput!) {\n  user {\n    uuid\n    careProviders(input: $input) {\n      firstName\n      lastName\n      avatarUrl\n      qualifications\n      bio\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetUserCareProviders","variables":{"input":{"providerType":"OS"}},"query":"query GetUserCareProviders($input: CareProviderInput!) {\n  user {\n    uuid\n    careProviders(input: $input) {\n      firstName\n      lastName\n      avatarUrl\n      qualifications\n      bio\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetDashboardPageButtonsToShow","variables":{},"query":"query GetDashboardPageButtonsToShow {\n  dashboardPageButtonsToShow {\n    shouldSeeAboutMyCoachPageLink\n    shouldSeeBalanceProgramLink\n    shouldSeeCanTransferToPhoenixLink\n    shouldSeeCompleteApplicationLink\n    shouldSeeIsEnsoEligibleLink\n    shouldSeeApplyToNewProgramLink\n    shouldSeeCanApplyLink\n    shouldSeePreferencesPageLink\n    shouldSeeProgramInformationPageLink\n    shouldSeeUnifiedCompleteApplicationLink\n    shouldSeeGlobalCompleteApplicationLink\n    __typename\n  }\n}\n"}
# {"operationName":"GetUser","variables":{},"query":"query GetUser {\n  user {\n    email\n    firstName\n    createdAt\n    dateOfBirth\n    uuid\n    languagePreference\n    sexAssigned\n    returning\n    isOptum\n    tags\n    applicationPathway {\n      indication\n      program\n      __typename\n    }\n    client {\n      identifier\n      availablePrograms\n      dmcEnabled\n      tabletRequired\n      globalProduct\n      config {\n        supportsUnification\n        m1Trial\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetUser","variables":{},"query":"query GetUser {\n  user {\n    email\n    firstName\n    createdAt\n    dateOfBirth\n    uuid\n    languagePreference\n    sexAssigned\n    returning\n    isOptum\n    tags\n    applicationPathway {\n      indication\n      program\n      __typename\n    }\n    client {\n      identifier\n      availablePrograms\n      dmcEnabled\n      tabletRequired\n      globalProduct\n      config {\n        supportsUnification\n        m1Trial\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetUser","variables":{},"query":"query GetUser {\n  user {\n    email\n    firstName\n    createdAt\n    dateOfBirth\n    uuid\n    languagePreference\n    sexAssigned\n    returning\n    isOptum\n    tags\n    applicationPathway {\n      indication\n      program\n      __typename\n    }\n    client {\n      identifier\n      availablePrograms\n      dmcEnabled\n      tabletRequired\n      globalProduct\n      config {\n        supportsUnification\n        m1Trial\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"dashboardUserApplications","variables":{},"query":"query dashboardUserApplications {\n  userApplications(\n    input: {type: [CORE, UNIFIED_ENTRY, GLOBAL_PRODUCT], includeClosed: true}\n  ) {\n    ...CommonApplicationUnionFields\n    ... on UnifiedEntryApplication {\n      indications {\n        bodyPart\n        acuity\n        priority\n        __typename\n      }\n      unifiedProgram: program\n      unifiedIndication: indication\n      __typename\n    }\n    ... on CoreApplication {\n      coreProgram: program\n      coreIndication: indication\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment CommonApplicationUnionFields on ApplicationBase {\n  __typename\n  id\n  type\n  progress\n  standing\n  rejectionReasons\n}\n"}
# {"operationName":"GetUserCareProviders","variables":{"input":{"providerType":"COACH"}},"query":"query GetUserCareProviders($input: CareProviderInput!) {\n  user {\n    uuid\n    careProviders(input: $input) {\n      firstName\n      lastName\n      avatarUrl\n      qualifications\n      bio\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetUserCareProviders","variables":{"input":{"providerType":"OS"}},"query":"query GetUserCareProviders($input: CareProviderInput!) {\n  user {\n    uuid\n    careProviders(input: $input) {\n      firstName\n      lastName\n      avatarUrl\n      qualifications\n      bio\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetDashboardPageButtonsToShow","variables":{},"query":"query GetDashboardPageButtonsToShow {\n  dashboardPageButtonsToShow {\n    shouldSeeAboutMyCoachPageLink\n    shouldSeeBalanceProgramLink\n    shouldSeeCanTransferToPhoenixLink\n    shouldSeeCompleteApplicationLink\n    shouldSeeIsEnsoEligibleLink\n    shouldSeeApplyToNewProgramLink\n    shouldSeeCanApplyLink\n    shouldSeePreferencesPageLink\n    shouldSeeProgramInformationPageLink\n    shouldSeeUnifiedCompleteApplicationLink\n    shouldSeeGlobalCompleteApplicationLink\n    __typename\n  }\n}\n"}
# {"operationName":"GetUser","variables":{},"query":"query GetUser {\n  user {\n    email\n    firstName\n    createdAt\n    dateOfBirth\n    uuid\n    languagePreference\n    sexAssigned\n    returning\n    isOptum\n    tags\n    applicationPathway {\n      indication\n      program\n      __typename\n    }\n    client {\n      identifier\n      availablePrograms\n      dmcEnabled\n      tabletRequired\n      globalProduct\n      config {\n        supportsUnification\n        m1Trial\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetUser","variables":{},"query":"query GetUser {\n  user {\n    email\n    firstName\n    createdAt\n    dateOfBirth\n    uuid\n    languagePreference\n    sexAssigned\n    returning\n    isOptum\n    tags\n    applicationPathway {\n      indication\n      program\n      __typename\n    }\n    client {\n      identifier\n      availablePrograms\n      dmcEnabled\n      tabletRequired\n      globalProduct\n      config {\n        supportsUnification\n        m1Trial\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetUser","variables":{},"query":"query GetUser {\n  user {\n    email\n    firstName\n    createdAt\n    dateOfBirth\n    uuid\n    languagePreference\n    sexAssigned\n    returning\n    isOptum\n    tags\n    applicationPathway {\n      indication\n      program\n      __typename\n    }\n    client {\n      identifier\n      availablePrograms\n      dmcEnabled\n      tabletRequired\n      globalProduct\n      config {\n        supportsUnification\n        m1Trial\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetPersonalReferralCode","variables":{},"query":"query GetPersonalReferralCode {\n  personalReferralCode {\n    referralKey\n    __typename\n  }\n}\n"}
# {"operationName":"dashboardUserApplications","variables":{},"query":"query dashboardUserApplications {\n  userApplications(\n    input: {type: [CORE, UNIFIED_ENTRY, GLOBAL_PRODUCT], includeClosed: true}\n  ) {\n    ...CommonApplicationUnionFields\n    ... on UnifiedEntryApplication {\n      indications {\n        bodyPart\n        acuity\n        priority\n        __typename\n      }\n      unifiedProgram: program\n      unifiedIndication: indication\n      __typename\n    }\n    ... on CoreApplication {\n      coreProgram: program\n      coreIndication: indication\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment CommonApplicationUnionFields on ApplicationBase {\n  __typename\n  id\n  type\n  progress\n  standing\n  rejectionReasons\n}\n"}
# {"operationName":"GetUserCareProviders","variables":{"input":{"providerType":"COACH"}},"query":"query GetUserCareProviders($input: CareProviderInput!) {\n  user {\n    uuid\n    careProviders(input: $input) {\n      firstName\n      lastName\n      avatarUrl\n      qualifications\n      bio\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetUserCareProviders","variables":{"input":{"providerType":"OS"}},"query":"query GetUserCareProviders($input: CareProviderInput!) {\n  user {\n    uuid\n    careProviders(input: $input) {\n      firstName\n      lastName\n      avatarUrl\n      qualifications\n      bio\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetDashboardPageButtonsToShow","variables":{},"query":"query GetDashboardPageButtonsToShow {\n  dashboardPageButtonsToShow {\n    shouldSeeAboutMyCoachPageLink\n    shouldSeeBalanceProgramLink\n    shouldSeeCanTransferToPhoenixLink\n    shouldSeeCompleteApplicationLink\n    shouldSeeIsEnsoEligibleLink\n    shouldSeeApplyToNewProgramLink\n    shouldSeeCanApplyLink\n    shouldSeePreferencesPageLink\n    shouldSeeProgramInformationPageLink\n    shouldSeeUnifiedCompleteApplicationLink\n    shouldSeeGlobalCompleteApplicationLink\n    __typename\n  }\n}\n"}
# {"operationName":"GetUser","variables":{},"query":"query GetUser {\n  user {\n    email\n    firstName\n    createdAt\n    dateOfBirth\n    uuid\n    languagePreference\n    sexAssigned\n    returning\n    isOptum\n    tags\n    applicationPathway {\n      indication\n      program\n      __typename\n    }\n    client {\n      identifier\n      availablePrograms\n      dmcEnabled\n      tabletRequired\n      globalProduct\n      config {\n        supportsUnification\n        m1Trial\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetUser","variables":{},"query":"query GetUser {\n  user {\n    email\n    firstName\n    createdAt\n    dateOfBirth\n    uuid\n    languagePreference\n    sexAssigned\n    returning\n    isOptum\n    tags\n    applicationPathway {\n      indication\n      program\n      __typename\n    }\n    client {\n      identifier\n      availablePrograms\n      dmcEnabled\n      tabletRequired\n      globalProduct\n      config {\n        supportsUnification\n        m1Trial\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetUser","variables":{},"query":"query GetUser {\n  user {\n    email\n    firstName\n    createdAt\n    dateOfBirth\n    uuid\n    languagePreference\n    sexAssigned\n    returning\n    isOptum\n    tags\n    applicationPathway {\n      indication\n      program\n      __typename\n    }\n    client {\n      identifier\n      availablePrograms\n      dmcEnabled\n      tabletRequired\n      globalProduct\n      config {\n        supportsUnification\n        m1Trial\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetUser","variables":{},"query":"query GetUser {\n  user {\n    email\n    firstName\n    createdAt\n    dateOfBirth\n    uuid\n    languagePreference\n    sexAssigned\n    returning\n    isOptum\n    tags\n    applicationPathway {\n      indication\n      program\n      __typename\n    }\n    client {\n      identifier\n      availablePrograms\n      dmcEnabled\n      tabletRequired\n      globalProduct\n      config {\n        supportsUnification\n        m1Trial\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"dashboardUserApplications","variables":{},"query":"query dashboardUserApplications {\n  userApplications(\n    input: {type: [CORE, UNIFIED_ENTRY, GLOBAL_PRODUCT], includeClosed: true}\n  ) {\n    ...CommonApplicationUnionFields\n    ... on UnifiedEntryApplication {\n      indications {\n        bodyPart\n        acuity\n        priority\n        __typename\n      }\n      unifiedProgram: program\n      unifiedIndication: indication\n      __typename\n    }\n    ... on CoreApplication {\n      coreProgram: program\n      coreIndication: indication\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment CommonApplicationUnionFields on ApplicationBase {\n  __typename\n  id\n  type\n  progress\n  standing\n  rejectionReasons\n}\n"}
# {"operationName":"GetUserCareProviders","variables":{"input":{"providerType":"OS"}},"query":"query GetUserCareProviders($input: CareProviderInput!) {\n  user {\n    uuid\n    careProviders(input: $input) {\n      firstName\n      lastName\n      avatarUrl\n      qualifications\n      bio\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetUserCareProviders","variables":{"input":{"providerType":"COACH"}},"query":"query GetUserCareProviders($input: CareProviderInput!) {\n  user {\n    uuid\n    careProviders(input: $input) {\n      firstName\n      lastName\n      avatarUrl\n      qualifications\n      bio\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetDashboardPageButtonsToShow","variables":{},"query":"query GetDashboardPageButtonsToShow {\n  dashboardPageButtonsToShow {\n    shouldSeeAboutMyCoachPageLink\n    shouldSeeBalanceProgramLink\n    shouldSeeCanTransferToPhoenixLink\n    shouldSeeCompleteApplicationLink\n    shouldSeeIsEnsoEligibleLink\n    shouldSeeApplyToNewProgramLink\n    shouldSeeCanApplyLink\n    shouldSeePreferencesPageLink\n    shouldSeeProgramInformationPageLink\n    shouldSeeUnifiedCompleteApplicationLink\n    shouldSeeGlobalCompleteApplicationLink\n    __typename\n  }\n}\n"}
# {"operationName":"GetPersonalReferralCode","variables":{},"query":"query GetPersonalReferralCode {\n  personalReferralCode {\n    referralKey\n    __typename\n  }\n}\n"}
# {"operationName":"GetUserContactMethod","variables":{},"query":"query GetUserContactMethod {\n  user {\n    uuid\n    contactMethod\n    __typename\n  }\n}\n"}
# {"operationName":"UpdateContactMethod","variables":{"contactMethodInput":{"contactMethod":["sms","call","email"]}},"query":"mutation UpdateContactMethod($contactMethodInput: UpdateContactMethodInput!) {\n  updateContactMethod(input: $contactMethodInput) {\n    contactMethod\n    __typename\n  }\n}\n"}
# {"operationName":"GetUser","variables":{},"query":"query GetUser {\n  user {\n    email\n    firstName\n    createdAt\n    dateOfBirth\n    uuid\n    languagePreference\n    sexAssigned\n    returning\n    isOptum\n    tags\n    applicationPathway {\n      indication\n      program\n      __typename\n    }\n    client {\n      identifier\n      availablePrograms\n      dmcEnabled\n      tabletRequired\n      globalProduct\n      config {\n        supportsUnification\n        m1Trial\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetPersonalReferralCode","variables":{},"query":"query GetPersonalReferralCode {\n  personalReferralCode {\n    referralKey\n    __typename\n  }\n}\n"}
# {"operationName":"GetUserCareProviders","variables":{"input":{"providerType":"COACH"}},"query":"query GetUserCareProviders($input: CareProviderInput!) {\n  user {\n    uuid\n    careProviders(input: $input) {\n      firstName\n      lastName\n      avatarUrl\n      qualifications\n      bio\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"dashboardUserApplications","variables":{},"query":"query dashboardUserApplications {\n  userApplications(\n    input: {type: [CORE, UNIFIED_ENTRY, GLOBAL_PRODUCT], includeClosed: true}\n  ) {\n    ...CommonApplicationUnionFields\n    ... on UnifiedEntryApplication {\n      indications {\n        bodyPart\n        acuity\n        priority\n        __typename\n      }\n      unifiedProgram: program\n      unifiedIndication: indication\n      __typename\n    }\n    ... on CoreApplication {\n      coreProgram: program\n      coreIndication: indication\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment CommonApplicationUnionFields on ApplicationBase {\n  __typename\n  id\n  type\n  progress\n  standing\n  rejectionReasons\n}\n"}
# {"operationName":"GetUserCareProviders","variables":{"input":{"providerType":"OS"}},"query":"query GetUserCareProviders($input: CareProviderInput!) {\n  user {\n    uuid\n    careProviders(input: $input) {\n      firstName\n      lastName\n      avatarUrl\n      qualifications\n      bio\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetDashboardPageButtonsToShow","variables":{},"query":"query GetDashboardPageButtonsToShow {\n  dashboardPageButtonsToShow {\n    shouldSeeAboutMyCoachPageLink\n    shouldSeeBalanceProgramLink\n    shouldSeeCanTransferToPhoenixLink\n    shouldSeeCompleteApplicationLink\n    shouldSeeIsEnsoEligibleLink\n    shouldSeeApplyToNewProgramLink\n    shouldSeeCanApplyLink\n    shouldSeePreferencesPageLink\n    shouldSeeProgramInformationPageLink\n    shouldSeeUnifiedCompleteApplicationLink\n    shouldSeeGlobalCompleteApplicationLink\n    __typename\n  }\n}\n"}
# {"operationName":"currentAdmin","variables":{},"query":"query currentAdmin {\n  admin {\n    firstName\n    lastName\n    uuid\n    role\n    email\n    avatarUrl\n    id\n    __typename\n  }\n}\n"}
# {"operationName":"countWorkflowsWithWorkflowTypes","variables":{"countWorkflowsFilters":{"adminUuids":["dcc3630b-30d4-4315-b670-e99ae244ff9b"],"workflowTypes":["first-action-plan","unread-messages","member-alert-reminder","action-plan-review","first-week-goal","pregnancy-status-change","offer-video-visit","maternity-milestones","first-week-check-in","action-plan-check-in","balance-assessment","action-plan-check-in","first-week-check-in","coach-call","enso-week-1","reengager","coach-escalation","weekly-enso-review","outreach-needed","member-health-log","balance-assessment"],"completedStates":["complete","dismiss","closed","outreach-sent-to-member","dismissed","user-transitioned-to-new-program","cancel-video-visit"],"useCoverage":true,"dueTaskEndDate":"2024-09-24T17:59:59.999Z","excludeStates":["complete","dismiss","awaiting-new","awaiting-plan","archive","closed","outreach-sent-to-member","dismissed","user-transitioned-to-new-program","pending","video-visit-already-scheduled-or-complete","closed","awaiting-message","awaiting-tag","post-fwg","cancel-video-visit","assigned-to-workflow","enso-ordered"],"countByPriority":true}},"query":"query countWorkflowsWithWorkflowTypes($countWorkflowsFilters: CountWorkflowsFiltersInputDto!) {\n  countWorkflowsWithWorkflowTypes(\n    countWorkflowsFiltersInputDto: $countWorkflowsFilters\n  ) {\n    results {\n      state\n      count\n      workflowType\n      __typename\n    }\n    total\n    subtotals {\n      workflowType\n      count\n      countByPriority {\n        low\n        high\n        unknown\n        __typename\n      }\n      __typename\n    }\n    errors {\n      error\n      fieldName\n      value\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"countWorkflowsWithWorkflowTypes","variables":{"countWorkflowsFilters":{"adminUuids":["dcc3630b-30d4-4315-b670-e99ae244ff9b"],"workflowTypes":["first-action-plan","unread-messages","member-alert-reminder","action-plan-review","first-week-goal","pregnancy-status-change","offer-video-visit","maternity-milestones","first-week-check-in","action-plan-check-in","balance-assessment","action-plan-check-in","first-week-check-in","coach-call","enso-week-1","reengager","coach-escalation","weekly-enso-review","outreach-needed","member-health-log","balance-assessment"],"completedStates":["complete","dismiss","closed","outreach-sent-to-member","dismissed","user-transitioned-to-new-program","cancel-video-visit"],"useCoverage":true,"completedAfterDate":"2024-09-22T18:00:00.000Z","completedBeforeDate":"2024-09-23T17:59:59.999Z"}},"query":"query countWorkflowsWithWorkflowTypes($countWorkflowsFilters: CountWorkflowsFiltersInputDto!) {\n  countWorkflowsWithWorkflowTypes(\n    countWorkflowsFiltersInputDto: $countWorkflowsFilters\n  ) {\n    results {\n      state\n      count\n      workflowType\n      __typename\n    }\n    total\n    subtotals {\n      workflowType\n      count\n      countByPriority {\n        low\n        high\n        unknown\n        __typename\n      }\n      __typename\n    }\n    errors {\n      error\n      fieldName\n      value\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"generateAIContentForUpcomingWorkflows","variables":{"input":{"type":"BATCH_GENERATE_MESSAGES"}},"query":"mutation generateAIContentForUpcomingWorkflows($input: PostGenerationInputDto!) {\n  generateAIContentForUpcomingWorkflows(input: $input) {\n    uuid\n    __typename\n  }\n}\n"}
# {"operationName":"generateAIContentForUpcomingWorkflows","variables":{"input":{"type":"BATCH_GENERATE_INSIGHTS"}},"query":"mutation generateAIContentForUpcomingWorkflows($input: PostGenerationInputDto!) {\n  generateAIContentForUpcomingWorkflows(input: $input) {\n    uuid\n    __typename\n  }\n}\n"}
# {"operationName":"countQueueWorkflowsWithWorkflowTypes","variables":{"countWorkflowsFilters":{"adminUuids":["dcc3630b-30d4-4315-b670-e99ae244ff9b"],"workflowTypes":["unread-messages","first-action-plan","action-plan-review","first-week-goal","member-alert-reminder","pregnancy-status-change","maternity-milestones","balance-assessment","member-health-log","enso-week-1","outreach-needed","reengager","weekly-enso-review","coach-escalation","action-plan-check-in","first-week-check-in","coach-call"],"dueTaskEndDate":"2024-09-24T17:59:59.999Z","excludeStates":["complete","dismiss","awaiting-new","awaiting-plan","archive","closed","outreach-sent-to-member","dismissed","user-transitioned-to-new-program","pending","video-visit-already-scheduled-or-complete","awaiting-message","awaiting-tag","post-fwg","cancel-video-visit","assigned-to-workflow","enso-ordered","acute-complete"],"completedStates":["complete","dismiss","awaiting-plan","archive","closed","outreach-sent-to-member","dismissed","user-transitioned-to-new-program","pending","video-visit-already-scheduled-or-complete","closed","cancel-video-visit","acute-complete"],"useCoverage":true}},"query":"query countQueueWorkflowsWithWorkflowTypes($countWorkflowsFilters: CountWorkflowsFiltersInputDto!) {\n  countWorkflowsWithWorkflowTypes(\n    countWorkflowsFiltersInputDto: $countWorkflowsFilters\n  ) {\n    total\n    subtotals {\n      workflowType\n      count\n      countByPriority {\n        high\n        low\n        unknown\n        __typename\n      }\n      __typename\n    }\n    errors {\n      error\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"countQueueWorkflowsWithWorkflowTypes","variables":{"countWorkflowsFilters":{"adminUuids":["dcc3630b-30d4-4315-b670-e99ae244ff9b"],"workflowTypes":["unread-messages","first-action-plan","action-plan-review","first-week-goal","member-alert-reminder","pregnancy-status-change","maternity-milestones","balance-assessment","member-health-log","enso-week-1","outreach-needed","reengager","weekly-enso-review","coach-escalation","action-plan-check-in","first-week-check-in","coach-call"],"completedAfterDate":"2024-09-22T18:00:00.000Z","completedBeforeDate":"2024-09-23T17:59:59.999Z","completedStates":["complete","dismiss","awaiting-plan","archive","closed","outreach-sent-to-member","dismissed","user-transitioned-to-new-program","pending","video-visit-already-scheduled-or-complete","closed","cancel-video-visit","acute-complete"],"useCoverage":true}},"query":"query countQueueWorkflowsWithWorkflowTypes($countWorkflowsFilters: CountWorkflowsFiltersInputDto!) {\n  countWorkflowsWithWorkflowTypes(\n    countWorkflowsFiltersInputDto: $countWorkflowsFilters\n  ) {\n    total\n    subtotals {\n      workflowType\n      count\n      countByPriority {\n        high\n        low\n        unknown\n        __typename\n      }\n      __typename\n    }\n    errors {\n      error\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"getWorkflowsForCoach","variables":{"workflowFiltersInput":{"pageSize":10,"pageNumber":1,"adminUuids":["dcc3630b-30d4-4315-b670-e99ae244ff9b"],"completedStates":["complete","dismiss","closed","dismissed","outreach-sent-to-member","user-transitioned-to-new-program","cancel-video-visit"],"useCoverage":true,"workflowTypes":["first-action-plan","unread-messages","member-alert-reminder","action-plan-review","first-week-goal","pregnancy-status-change","offer-video-visit","maternity-milestones","first-week-check-in","action-plan-check-in","balance-assessment","action-plan-check-in","first-week-check-in","coach-call","enso-week-1","reengager","coach-escalation","weekly-enso-review","outreach-needed","member-health-log","balance-assessment"],"excludeStates":["complete","dismiss","awaiting-new","awaiting-plan","archive","closed","outreach-sent-to-member","dismissed","user-transitioned-to-new-program","pending","video-visit-already-scheduled-or-complete","closed","awaiting-message","awaiting-tag","post-fwg","cancel-video-visit","assigned-to-workflow","enso-ordered"],"dueTaskEndDate":"2024-09-24T17:59:59.999Z"}},"query":"query getWorkflowsForCoach($workflowFiltersInput: WorkflowListFiltersInputDto!) {\n  getWorkflowsByFilter(workflowFiltersInputDto: $workflowFiltersInput) {\n    id\n    workflows {\n      id\n      lastCompletedAt\n      ...WorkflowDueDateFields\n      ...WorkflowMemberData\n      ...WorkflowTypeCustomFieldsActionPlans\n      ...WorkflowCreatedAt\n      ...WorkflowTaskFields\n      ...WorkflowHealthLog\n      __typename\n    }\n    pageSize\n    pageNumber\n    __typename\n  }\n}\n\nfragment WorkflowDueDateFields on WorkflowPayload {\n  type\n  latestTaskDate\n  isPastDue\n  __typename\n}\n\nfragment WorkflowMemberData on WorkflowPayload {\n  patient {\n    firstName\n    lastName\n    id\n    uuid\n    applicationPathway {\n      program\n      indication\n      __typename\n    }\n    __typename\n  }\n  memberAlerts {\n    category\n    description\n    endAt\n    startAt\n    remindAt\n    paused\n    __typename\n  }\n  indications {\n    name\n    priority\n    __typename\n  }\n  __typename\n}\n\nfragment WorkflowTypeCustomFieldsActionPlans on WorkflowPayload {\n  type\n  customFields\n  state\n  actionPlans {\n    userUuid\n    createdBy\n    status\n    __typename\n  }\n  __typename\n}\n\nfragment WorkflowCreatedAt on WorkflowPayload {\n  createdAt\n  __typename\n}\n\nfragment WorkflowTaskFields on WorkflowPayload {\n  latestTaskId\n  tasks {\n    type\n    id\n    __typename\n  }\n  __typename\n}\n\nfragment WorkflowHealthLog on WorkflowPayload {\n  healthLog {\n    id\n    note\n    occurred_at\n    user_uuid\n    uuid\n    isMultiShim\n    pain_reports {\n      baselineScore\n      body_part\n      change\n      date\n      id\n      indication_urn\n      isPathwayActive\n      priority\n      programName\n      score\n      uuid\n      hideTrend\n      __typename\n    }\n    __typename\n  }\n  __typename\n}\n"}
# {"operationName":"UserInfo","variables":{"uuid":"50166212"},"query":"query UserInfo($uuid: ID!) {\n  user(uuid: $uuid) {\n    id\n    firstName\n    lastName\n    gender\n    email\n    phoneNumber\n    addressOne\n    addressTwo\n    city\n    stateOfResidence\n    postalCode\n    dateOfBirth\n    timezone\n    uuid\n    tagList\n    contactMethod\n    allowsOffshore\n    pathways {\n      id\n      indication\n      isActive\n      level\n      type\n      __typename\n    }\n    applicationPathway {\n      program\n      indication\n      screeningId\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"UserInfo","variables":{"uuid":"50166217"},"query":"query UserInfo($uuid: ID!) {\n  user(uuid: $uuid) {\n    id\n    firstName\n    lastName\n    gender\n    email\n    phoneNumber\n    addressOne\n    addressTwo\n    city\n    stateOfResidence\n    postalCode\n    dateOfBirth\n    timezone\n    uuid\n    tagList\n    contactMethod\n    allowsOffshore\n    pathways {\n      id\n      indication\n      isActive\n      level\n      type\n      __typename\n    }\n    applicationPathway {\n      program\n      indication\n      screeningId\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"currentAdmin","variables":{},"query":"query currentAdmin {\n  admin {\n    firstName\n    lastName\n    uuid\n    role\n    email\n    avatarUrl\n    id\n    __typename\n  }\n}\n"}
# {"operationName":"countQueueWorkflowsWithWorkflowTypes","variables":{"countWorkflowsFilters":{"adminUuids":["dcc3630b-30d4-4315-b670-e99ae244ff9b"],"workflowTypes":["unread-messages","first-action-plan","action-plan-review","first-week-goal","member-alert-reminder","pregnancy-status-change","maternity-milestones","balance-assessment","member-health-log","enso-week-1","outreach-needed","reengager","weekly-enso-review","coach-escalation","action-plan-check-in","first-week-check-in","coach-call"],"completedAfterDate":"2024-09-22T18:00:00.000Z","completedBeforeDate":"2024-09-23T17:59:59.999Z","completedStates":["complete","dismiss","awaiting-plan","archive","closed","outreach-sent-to-member","dismissed","user-transitioned-to-new-program","pending","video-visit-already-scheduled-or-complete","closed","cancel-video-visit","acute-complete"],"useCoverage":true}},"query":"query countQueueWorkflowsWithWorkflowTypes($countWorkflowsFilters: CountWorkflowsFiltersInputDto!) {\n  countWorkflowsWithWorkflowTypes(\n    countWorkflowsFiltersInputDto: $countWorkflowsFilters\n  ) {\n    total\n    subtotals {\n      workflowType\n      count\n      countByPriority {\n        high\n        low\n        unknown\n        __typename\n      }\n      __typename\n    }\n    errors {\n      error\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"countQueueWorkflowsWithWorkflowTypes","variables":{"countWorkflowsFilters":{"adminUuids":["dcc3630b-30d4-4315-b670-e99ae244ff9b"],"workflowTypes":["unread-messages","first-action-plan","action-plan-review","first-week-goal","member-alert-reminder","pregnancy-status-change","maternity-milestones","balance-assessment","member-health-log","enso-week-1","outreach-needed","reengager","weekly-enso-review","coach-escalation","action-plan-check-in","first-week-check-in","coach-call"],"dueTaskEndDate":"2024-09-24T17:59:59.999Z","excludeStates":["complete","dismiss","awaiting-new","awaiting-plan","archive","closed","outreach-sent-to-member","dismissed","user-transitioned-to-new-program","pending","video-visit-already-scheduled-or-complete","awaiting-message","awaiting-tag","post-fwg","cancel-video-visit","assigned-to-workflow","enso-ordered","acute-complete"],"completedStates":["complete","dismiss","awaiting-plan","archive","closed","outreach-sent-to-member","dismissed","user-transitioned-to-new-program","pending","video-visit-already-scheduled-or-complete","closed","cancel-video-visit","acute-complete"],"useCoverage":true}},"query":"query countQueueWorkflowsWithWorkflowTypes($countWorkflowsFilters: CountWorkflowsFiltersInputDto!) {\n  countWorkflowsWithWorkflowTypes(\n    countWorkflowsFiltersInputDto: $countWorkflowsFilters\n  ) {\n    total\n    subtotals {\n      workflowType\n      count\n      countByPriority {\n        high\n        low\n        unknown\n        __typename\n      }\n      __typename\n    }\n    errors {\n      error\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"countWorkflowsWithWorkflowTypes","variables":{"countWorkflowsFilters":{"adminUuids":["dcc3630b-30d4-4315-b670-e99ae244ff9b"],"workflowTypes":["first-action-plan","unread-messages","member-alert-reminder","action-plan-review","first-week-goal","pregnancy-status-change","offer-video-visit","maternity-milestones","first-week-check-in","action-plan-check-in","balance-assessment","action-plan-check-in","first-week-check-in","coach-call","enso-week-1","reengager","coach-escalation","weekly-enso-review","outreach-needed","member-health-log","balance-assessment"],"completedStates":["complete","dismiss","closed","outreach-sent-to-member","dismissed","user-transitioned-to-new-program","cancel-video-visit"],"useCoverage":true,"dueTaskEndDate":"2024-09-24T17:59:59.999Z","excludeStates":["complete","dismiss","awaiting-new","awaiting-plan","archive","closed","outreach-sent-to-member","dismissed","user-transitioned-to-new-program","pending","video-visit-already-scheduled-or-complete","closed","awaiting-message","awaiting-tag","post-fwg","cancel-video-visit","assigned-to-workflow","enso-ordered"],"countByPriority":true}},"query":"query countWorkflowsWithWorkflowTypes($countWorkflowsFilters: CountWorkflowsFiltersInputDto!) {\n  countWorkflowsWithWorkflowTypes(\n    countWorkflowsFiltersInputDto: $countWorkflowsFilters\n  ) {\n    results {\n      state\n      count\n      workflowType\n      __typename\n    }\n    total\n    subtotals {\n      workflowType\n      count\n      countByPriority {\n        low\n        high\n        unknown\n        __typename\n      }\n      __typename\n    }\n    errors {\n      error\n      fieldName\n      value\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"countWorkflowsWithWorkflowTypes","variables":{"countWorkflowsFilters":{"adminUuids":["dcc3630b-30d4-4315-b670-e99ae244ff9b"],"workflowTypes":["first-action-plan","unread-messages","member-alert-reminder","action-plan-review","first-week-goal","pregnancy-status-change","offer-video-visit","maternity-milestones","first-week-check-in","action-plan-check-in","balance-assessment","action-plan-check-in","first-week-check-in","coach-call","enso-week-1","reengager","coach-escalation","weekly-enso-review","outreach-needed","member-health-log","balance-assessment"],"completedStates":["complete","dismiss","closed","outreach-sent-to-member","dismissed","user-transitioned-to-new-program","cancel-video-visit"],"useCoverage":true,"completedAfterDate":"2024-09-22T18:00:00.000Z","completedBeforeDate":"2024-09-23T17:59:59.999Z"}},"query":"query countWorkflowsWithWorkflowTypes($countWorkflowsFilters: CountWorkflowsFiltersInputDto!) {\n  countWorkflowsWithWorkflowTypes(\n    countWorkflowsFiltersInputDto: $countWorkflowsFilters\n  ) {\n    results {\n      state\n      count\n      workflowType\n      __typename\n    }\n    total\n    subtotals {\n      workflowType\n      count\n      countByPriority {\n        low\n        high\n        unknown\n        __typename\n      }\n      __typename\n    }\n    errors {\n      error\n      fieldName\n      value\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"getWorkflowsForCoach","variables":{"workflowFiltersInput":{"pageSize":10,"pageNumber":1,"adminUuids":["dcc3630b-30d4-4315-b670-e99ae244ff9b"],"completedStates":["complete","dismiss","closed","dismissed","outreach-sent-to-member","user-transitioned-to-new-program","cancel-video-visit"],"useCoverage":true,"workflowTypes":["first-action-plan","unread-messages","member-alert-reminder","action-plan-review","first-week-goal","pregnancy-status-change","offer-video-visit","maternity-milestones","first-week-check-in","action-plan-check-in","balance-assessment","action-plan-check-in","first-week-check-in","coach-call","enso-week-1","reengager","coach-escalation","weekly-enso-review","outreach-needed","member-health-log","balance-assessment"],"excludeStates":["complete","dismiss","awaiting-new","awaiting-plan","archive","closed","outreach-sent-to-member","dismissed","user-transitioned-to-new-program","pending","video-visit-already-scheduled-or-complete","closed","awaiting-message","awaiting-tag","post-fwg","cancel-video-visit","assigned-to-workflow","enso-ordered"],"dueTaskEndDate":"2024-09-24T17:59:59.999Z"}},"query":"query getWorkflowsForCoach($workflowFiltersInput: WorkflowListFiltersInputDto!) {\n  getWorkflowsByFilter(workflowFiltersInputDto: $workflowFiltersInput) {\n    id\n    workflows {\n      id\n      lastCompletedAt\n      ...WorkflowDueDateFields\n      ...WorkflowMemberData\n      ...WorkflowTypeCustomFieldsActionPlans\n      ...WorkflowCreatedAt\n      ...WorkflowTaskFields\n      ...WorkflowHealthLog\n      __typename\n    }\n    pageSize\n    pageNumber\n    __typename\n  }\n}\n\nfragment WorkflowDueDateFields on WorkflowPayload {\n  type\n  latestTaskDate\n  isPastDue\n  __typename\n}\n\nfragment WorkflowMemberData on WorkflowPayload {\n  patient {\n    firstName\n    lastName\n    id\n    uuid\n    applicationPathway {\n      program\n      indication\n      __typename\n    }\n    __typename\n  }\n  memberAlerts {\n    category\n    description\n    endAt\n    startAt\n    remindAt\n    paused\n    __typename\n  }\n  indications {\n    name\n    priority\n    __typename\n  }\n  __typename\n}\n\nfragment WorkflowTypeCustomFieldsActionPlans on WorkflowPayload {\n  type\n  customFields\n  state\n  actionPlans {\n    userUuid\n    createdBy\n    status\n    __typename\n  }\n  __typename\n}\n\nfragment WorkflowCreatedAt on WorkflowPayload {\n  createdAt\n  __typename\n}\n\nfragment WorkflowTaskFields on WorkflowPayload {\n  latestTaskId\n  tasks {\n    type\n    id\n    __typename\n  }\n  __typename\n}\n\nfragment WorkflowHealthLog on WorkflowPayload {\n  healthLog {\n    id\n    note\n    occurred_at\n    user_uuid\n    uuid\n    isMultiShim\n    pain_reports {\n      baselineScore\n      body_part\n      change\n      date\n      id\n      indication_urn\n      isPathwayActive\n      priority\n      programName\n      score\n      uuid\n      hideTrend\n      __typename\n    }\n    __typename\n  }\n  __typename\n}\n"}
# {"operationName":"UserInfo","variables":{"uuid":"50166212"},"query":"query UserInfo($uuid: ID!) {\n  user(uuid: $uuid) {\n    id\n    firstName\n    lastName\n    gender\n    email\n    phoneNumber\n    addressOne\n    addressTwo\n    city\n    stateOfResidence\n    postalCode\n    dateOfBirth\n    timezone\n    uuid\n    tagList\n    contactMethod\n    allowsOffshore\n    pathways {\n      id\n      indication\n      isActive\n      level\n      type\n      __typename\n    }\n    applicationPathway {\n      program\n      indication\n      screeningId\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"UserInfo","variables":{"uuid":"50166217"},"query":"query UserInfo($uuid: ID!) {\n  user(uuid: $uuid) {\n    id\n    firstName\n    lastName\n    gender\n    email\n    phoneNumber\n    addressOne\n    addressTwo\n    city\n    stateOfResidence\n    postalCode\n    dateOfBirth\n    timezone\n    uuid\n    tagList\n    contactMethod\n    allowsOffshore\n    pathways {\n      id\n      indication\n      isActive\n      level\n      type\n      __typename\n    }\n    applicationPathway {\n      program\n      indication\n      screeningId\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"countWorkflowsWithWorkflowTypes","variables":{"countWorkflowsFilters":{"adminUuids":["dcc3630b-30d4-4315-b670-e99ae244ff9b"],"workflowTypes":["first-action-plan","unread-messages","member-alert-reminder","action-plan-review","first-week-goal","pregnancy-status-change","offer-video-visit","maternity-milestones","first-week-check-in","action-plan-check-in","balance-assessment","action-plan-check-in","first-week-check-in","coach-call","enso-week-1","reengager","coach-escalation","weekly-enso-review","outreach-needed","member-health-log","balance-assessment"],"completedStates":["complete","dismiss","closed","outreach-sent-to-member","dismissed","user-transitioned-to-new-program","cancel-video-visit"],"useCoverage":true,"dueTaskEndDate":"2024-09-24T17:59:59.999Z","excludeStates":["complete","dismiss","awaiting-new","awaiting-plan","archive","closed","outreach-sent-to-member","dismissed","user-transitioned-to-new-program","pending","video-visit-already-scheduled-or-complete","closed","awaiting-message","awaiting-tag","post-fwg","cancel-video-visit","assigned-to-workflow","enso-ordered"],"countByPriority":true}},"query":"query countWorkflowsWithWorkflowTypes($countWorkflowsFilters: CountWorkflowsFiltersInputDto!) {\n  countWorkflowsWithWorkflowTypes(\n    countWorkflowsFiltersInputDto: $countWorkflowsFilters\n  ) {\n    results {\n      state\n      count\n      workflowType\n      __typename\n    }\n    total\n    subtotals {\n      workflowType\n      count\n      countByPriority {\n        low\n        high\n        unknown\n        __typename\n      }\n      __typename\n    }\n    errors {\n      error\n      fieldName\n      value\n      __typename\n    }\n    __typename\n  }\n}\n"}
# ...
# {"operationName":"submitSurveyAnswers","variables":{"input":{"surveyId":"e7bad9cd-1323-468e-96f6-35e51d5ecf05","surveyKey":"aqAcuteBackV1Exp","pageIndexCompleted":1,"answers":[{"questionKey":"hoursWorkedPerWeek","questionTag":"wpai","questionLabel":"In general, how many hours per week do you usually work?*","value":"2"},{"questionKey":"hoursMissedHealthOptional","questionTag":"wpai","questionLabel":"During the past seven days, how many hours did you miss from work due to back pain?*","value":"2"},{"questionKey":"hoursMissedHealthOptionalCheckbox","questionTag":"wpai","questionLabel":"During the past seven days, how many hours did you miss from work due to back pain?*","value":"false"},{"questionKey":"healthProdEffect","questionTag":"wpai","questionLabel":"During the past seven days, how much did your back pain affect your productivity while you were working?*","value":"3"}]}},"query":"mutation submitSurveyAnswers($input: SubmitSurveyAnswersInput!) {\n  submitSurveyAnswers(input: $input) {\n    survey {\n      id\n      key\n      pageIndexCompleted\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"submitSurveyAnswers","variables":{"input":{"surveyId":"e7bad9cd-1323-468e-96f6-35e51d5ecf05","surveyKey":"aqAcuteBackV1Exp","pageIndexCompleted":2,"answers":[{"questionKey":"rmdq11Walk","questionTag":"rmdq11","questionLabel":"I walk more slowly than usual because of my pain.*","value":"1"},{"questionKey":"rmdq11Handrail","questionTag":"rmdq11","questionLabel":"Because of my pain, I use a handrail to get upstairs.*","value":"1"},{"questionKey":"rmdq11Hold","questionTag":"rmdq11","questionLabel":"Because of my pain, I have to hold on to something to get out of an easy chair.*","value":"0"},{"questionKey":"rmdq11Dressed","questionTag":"rmdq11","questionLabel":"I get dressed more slowly than usual because of my pain.*","value":"1"},{"questionKey":"rmdq11Periods","questionTag":"rmdq11","questionLabel":"I only stand up for short periods of time because of my pain.*","value":"1"},{"questionKey":"rmdq11Bend","questionTag":"rmdq11","questionLabel":"Because of my pain, I try not to bend or kneel down.*","value":"1"},{"questionKey":"rmdq11Chair","questionTag":"rmdq11","questionLabel":"I find it difficult to get out of a chair because of my pain.*","value":"1"},{"questionKey":"rmdq11Socks","questionTag":"rmdq11","questionLabel":"I have trouble putting on my socks (or stockings) because of my pain.*","value":"0"},{"questionKey":"rmdq11Distances","questionTag":"rmdq11","questionLabel":"I only walk short distances because of my pain.*","value":"1"},{"questionKey":"rmdq11Heavy","questionTag":"rmdq11","questionLabel":"I avoid heavy jobs around the house because of my pain.*","value":"1"},{"questionKey":"rmdq11Upstairs","questionTag":"rmdq11","questionLabel":"Because of my pain, I go upstairs more slowly than usual.*","value":"0"}]}},"query":"mutation submitSurveyAnswers($input: SubmitSurveyAnswersInput!) {\n  submitSurveyAnswers(input: $input) {\n    survey {\n      id\n      key\n      pageIndexCompleted\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"submitSurveyAnswers","variables":{"input":{"surveyId":"e7bad9cd-1323-468e-96f6-35e51d5ecf05","surveyKey":"aqAcuteBackV1Exp","pageIndexCompleted":3,"answers":[{"questionKey":"painDiagnosis","questionTag":"impact","questionLabel":"Have you received a diagnosis from a physician regarding your back pain in the past 90 days?*","value":"yes"},{"questionKey":"healthcareUtilization","questionTag":"impact","questionLabel":"In the past month, have you had any of the following for your back pain?*","value":["office_visit_with_doctor"]},{"questionKey":"upcomingSurgeries","questionTag":"impact","questionLabel":"Do you have any upcoming surgeries or procedures scheduled for your back in the next 2 months?*","value":"no"},{"questionKey":"surgeryChanceNextYear","questionTag":"impact","questionLabel":"What do you think are the chances you will have back surgery in the next year?*","value":"18"},{"questionKey":"medication","questionTag":"medical","questionLabel":"Please list any medications you are currently taking.*","value":"test"},{"questionKey":"heightFt","questionTag":"bodyInfo","questionLabel":"What is your height?*","value":"6"},{"questionKey":"heightIn","questionTag":"bodyInfo","questionLabel":"What is your height?*","value":"1"},{"questionKey":"weight","questionTag":"bodyInfo","questionLabel":"What is your weight?*","value":"252"}]}},"query":"mutation submitSurveyAnswers($input: SubmitSurveyAnswersInput!) {\n  submitSurveyAnswers(input: $input) {\n    survey {\n      id\n      key\n      pageIndexCompleted\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"submitSurveyAnswers","variables":{"input":{"surveyId":"e7bad9cd-1323-468e-96f6-35e51d5ecf05","surveyKey":"aqAcuteBackV1Exp","pageIndexCompleted":4,"answers":[{"questionKey":"spinalFracture","questionTag":"painBasic","questionLabel":"Have you ever been diagnosed with a spinal fracture?*","value":"yes"},{"questionKey":"cancerDiagnosis","questionTag":"painBasic","questionLabel":"Have you ever been diagnosed with cancer?*","value":"yes"},{"questionKey":"unexplainedWeightLoss","questionTag":"painBasic","questionLabel":"In the past 6 months, have you experienced significant, unexplained weight loss?*","value":"no"},{"questionKey":"fallsDueToLimitations","questionTag":"painBasic","questionLabel":"Have you had any falls due to weakness, balance, vision, or other limitations in the past 6 months?*","value":"no"},{"questionKey":"recentSurgery","questionTag":"painBasic","questionLabel":"Have you had surgery in the past 6 months?*","value":"no"},{"questionKey":"recentInjury","questionTag":"painBasic","questionLabel":"Have you experienced trauma or significant injury to your back in the past 3 months?*","value":"yes"},{"questionKey":"unexplainedBowelMovements","questionTag":"painBasic","questionLabel":"In the past 2 weeks, have you experienced any changes in your bowel or bladder function?*","value":"no"},{"questionKey":"unexplainedWeakness","questionTag":"painBasic","questionLabel":"In the past 2 weeks, have you experienced any unexplained progressive weakness or numbness in your legs, arms, or hands?*","value":"no"},{"questionKey":"unexplainedNumbnessGroin","questionTag":"painBasic","questionLabel":"In the past 2 weeks, have you experienced any unexplained progressive numbness in the groin or buttocks?*","value":"no"},{"questionKey":"standWithHelp","questionTag":"painBasic","questionLabel":"Do you need assistance from another person when standing up from a chair?*","value":"no"},{"questionKey":"avoidedExercise","questionTag":"painBasic","questionLabel":"Do you currently have any exercise restrictions or movement precautions from your physician or physical therapist?*","value":"no"},{"questionKey":"otherConditions","questionTag":"painBasic","questionLabel":"Please list any other current medical conditions that you have.*","value":"rwar"},{"questionKey":"spinalFractureExerciseClearance","questionTag":"redFlagFollowUps","questionLabel":"Related to your spinal fracture, have you been cleared by a physician to participate in unsupervised, light exercise?*","value":"yes"},{"questionKey":"recentInjuryExerciseClearance","questionTag":"redFlagFollowUps","questionLabel":"Since that trauma or injury, have you been cleared by a physician to participate in unsupervised, light exercise?*","value":"yes"},{"questionKey":"cancerDiagnosisExerciseClearance","questionTag":"redFlagFollowUps","questionLabel":"Related to your cancer diagnosis and/or treatment, have you been cleared by a physician to participate in unsupervised, light exercise?*","value":"yes"}]}},"query":"mutation submitSurveyAnswers($input: SubmitSurveyAnswersInput!) {\n  submitSurveyAnswers(input: $input) {\n    survey {\n      id\n      key\n      pageIndexCompleted\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"completeSurvey","variables":{"input":{"surveyId":"e7bad9cd-1323-468e-96f6-35e51d5ecf05"}},"query":"mutation completeSurvey($input: CompleteSurveyInput!) {\n  completeSurvey(input: $input) {\n    application {\n      program\n      progress\n      standing\n      currentSurvey {\n        type\n        __typename\n      }\n      rejectionReasons\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetCurrentApplication","variables":{"input":{"type":"CORE"}},"query":"query GetCurrentApplication($input: GetApplicationInput) {\n  currentApplication(input: $input) {\n    ...CommonApplicationFields\n    currentSurvey {\n      ...CommonSurveyFields\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment CommonApplicationFields on Application {\n  id\n  type\n  progress\n  standing\n  program\n  indication\n  rejectionReasons\n  __typename\n}\n\nfragment CommonSurveyFields on Survey {\n  id\n  type\n  key\n  progress\n  pageIndexCompleted\n  defaultAnswerValues {\n    questionKey\n    value\n    __typename\n  }\n  surveyQuestionChoices {\n    key\n    type\n    choices {\n      label\n      value\n      metadata\n      __typename\n    }\n    __typename\n  }\n  __typename\n}\n"}
# {"operationName":"submitSurveyAnswers","variables":{"input":{"surveyId":"1eddc1de-8c17-4584-b7ba-20c18519a2a1","surveyKey":"moodV1","pageIndexCompleted":0,"answers":[{"questionKey":"gadOnEdge","questionTag":"anxiety","questionLabel":"Feeling nervous, anxious, or on edge*","value":"1"},{"questionKey":"gadControlWorrying","questionTag":"anxiety","questionLabel":"Not being able to stop or control worrying*","value":"1"},{"questionKey":"phqDoingThings","questionTag":"depression","questionLabel":"Little interest or pleasure in doing things*","value":"1"},{"questionKey":"phqFeelingDepressed","questionTag":"depression","questionLabel":"Feeling down, depressed or hopeless*","value":"1"}]}},"query":"mutation submitSurveyAnswers($input: SubmitSurveyAnswersInput!) {\n  submitSurveyAnswers(input: $input) {\n    survey {\n      id\n      key\n      pageIndexCompleted\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"completeSurvey","variables":{"input":{"surveyId":"1eddc1de-8c17-4584-b7ba-20c18519a2a1"}},"query":"mutation completeSurvey($input: CompleteSurveyInput!) {\n  completeSurvey(input: $input) {\n    application {\n      program\n      progress\n      standing\n      currentSurvey {\n        type\n        __typename\n      }\n      rejectionReasons\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetCurrentApplication","variables":{"input":{"type":"CORE"}},"query":"query GetCurrentApplication($input: GetApplicationInput) {\n  currentApplication(input: $input) {\n    ...CommonApplicationFields\n    currentSurvey {\n      ...CommonSurveyFields\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment CommonApplicationFields on Application {\n  id\n  type\n  progress\n  standing\n  program\n  indication\n  rejectionReasons\n  __typename\n}\n\nfragment CommonSurveyFields on Survey {\n  id\n  type\n  key\n  progress\n  pageIndexCompleted\n  defaultAnswerValues {\n    questionKey\n    value\n    __typename\n  }\n  surveyQuestionChoices {\n    key\n    type\n    choices {\n      label\n      value\n      metadata\n      __typename\n    }\n    __typename\n  }\n  __typename\n}\n"}
# {"operationName":"submitSurveyAnswers","variables":{"input":{"surveyId":"d829aff2-9e6e-41d1-9542-dd650d947902","surveyKey":"profileAcuteV1","pageIndexCompleted":0,"answers":[{"questionKey":"gender","questionTag":"userProfile","questionLabel":"What is your current gender identity?*","value":"male"},{"questionKey":"occupation","questionTag":"userProfile","questionLabel":"What is your occupation?*","value":"test"},{"questionKey":"occupationCheckbox","questionTag":"userProfile","questionLabel":"What is your occupation?*","value":"false"},{"questionKey":"bio","questionTag":"userProfile","questionLabel":"What are your interests and hobbies?*","value":"test"},{"questionKey":"addressOne","questionTag":"userAddress","questionLabel":"Address line 1*","value":"test"},{"questionKey":"addressTwo","questionTag":"userAddress","questionLabel":"Address line 2 (optional)","value":""},{"questionKey":"city","questionTag":"userAddress","questionLabel":"City*","value":"test"},{"questionKey":"stateOfResidence","questionTag":"userAddress","questionLabel":"State*","value":"MA"},{"questionKey":"postalCode","questionTag":"userAddress","questionLabel":"ZIP Code*","value":"12345"},{"questionKey":"phoneNumber","questionTag":"userProfile","questionLabel":"What is your mobile number?*","value":"(705) 521-5212"}]}},"query":"mutation submitSurveyAnswers($input: SubmitSurveyAnswersInput!) {\n  submitSurveyAnswers(input: $input) {\n    survey {\n      id\n      key\n      pageIndexCompleted\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"completeSurvey","variables":{"input":{"surveyId":"d829aff2-9e6e-41d1-9542-dd650d947902"}},"query":"mutation completeSurvey($input: CompleteSurveyInput!) {\n  completeSurvey(input: $input) {\n    application {\n      program\n      progress\n      standing\n      currentSurvey {\n        type\n        __typename\n      }\n      rejectionReasons\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"getApplicationProcessingState","variables":{"applicationType":"CORE"},"query":"query getApplicationProcessingState($applicationType: ApplicationType!) {\n  currentApplication(input: {type: $applicationType}) {\n    id\n    processing {\n      state\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetUser","variables":{},"query":"query GetUser {\n  user {\n    email\n    firstName\n    createdAt\n    dateOfBirth\n    uuid\n    languagePreference\n    sexAssigned\n    returning\n    isOptum\n    tags\n    applicationPathway {\n      indication\n      program\n      __typename\n    }\n    client {\n      identifier\n      availablePrograms\n      dmcEnabled\n      tabletRequired\n      globalProduct\n      config {\n        supportsUnification\n        m1Trial\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
# {"operationName":"GetCurrentApplication","variables":{"input":{"type":"CORE"}},"query":"query GetCurrentApplication($input: GetApplicationInput) {\n  currentApplication(input: $input) {\n    ...CommonApplicationFields\n    currentSurvey {\n      ...CommonSurveyFields\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment CommonApplicationFields on Application {\n  id\n  type\n  progress\n  standing\n  program\n  indication\n  rejectionReasons\n  __typename\n}\n\nfragment CommonSurveyFields on Survey {\n  id\n  type\n  key\n  progress\n  pageIndexCompleted\n  defaultAnswerValues {\n    questionKey\n    value\n    __typename\n  }\n  surveyQuestionChoices {\n    key\n    type\n    choices {\n      label\n      value\n      metadata\n      __typename\n    }\n    __typename\n  }\n  __typename\n}\n"}
# {"operationName":"GetPersonalReferralCode","variables":{},"query":"query GetPersonalReferralCode {\n  personalReferralCode {\n    referralKey\n    __typename\n  }\n}\n"}
# {"operationName":"refresh","variables":{},"query":"mutation refresh {\n  refresh {\n    accessToken\n    accessExpiry\n    refreshExpiry\n    roles\n    adminId\n    __typename\n  }\n}\n"}
# Filtered CSV file with unique endpoint-operationName combinations has been created: 'graphql_endpoint_operation_combinations.csv'
# C:\Users\nnaye\AppData\Local\Temp\ipykernel_9984\4197956976.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   graphql_df['operationName'] = graphql_df['request_body'].apply(extract_operation_name)
